# %%
import pandas as pd
location = "inspections.csv"
df = pd.read_csv(location)
df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#   activity_date employee_id          facility_address  facility_city  \
# 0    2017-05-09   EE0000593       17660 CHATSWORTH ST  GRANADA HILLS
# 1    2017-04-10   EE0000126    3615 PACIFIC COAST HWY       TORRANCE
# 2    2017-04-04   EE0000593       17515 CHATSWORTH ST  GRANADA HILLS
# 3    2017-08-15   EE0000971  44455 VALLEY CENTRAL WAY      LANCASTER
# 4    2016-09-26   EE0000145            11700 SOUTH ST        ARTESIA
#
#   facility_id               facility_name facility_state facility_zip grade  \
# 0   FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344     A
# ...

# %%
len(df)
# Out:
# 191371

# %%
numActive = len(df[(df["program_status"] == "ACTIVE")]) # finding number of active restaurants 
print(numActive)
# Out:
# 169477

# %%
highactive = len(df[(df["program_status"] == "ACTIVE") & (df["score"] >= 90)])
print(highactive)
# restaurants that are active with a score of an A
# Out:
# 161271

# %%
161271/169477 # 95% of active restaurnts receive a score of an A
# Out:
# 0.9515804504446032

# %%
import pandas as pd
location2 = "violations.csv"
df = pd.read_csv(location2)
df.head()
# Out:
#    points serial_number violation_code  \
# 0       1     DAJ5UNMSF           F044
# 1       4     DAT2HKIRE           F007
# 2       1     DAT2HKIRE           F033
# 3       1     DAT2HKIRE           F035
# 4       1     DAQN0I8EA           F033
#
#                                violation_description   violation_status
# 0  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 1     # 07. Proper hot and cold holding temperatures  OUT OF COMPLIANCE
# 2  # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE
# 3  # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE
# 4  # 33. Nonfood-contact surfaces clean and in go...  OUT OF COMPLIANCE

# %%
len(df)
# Out:
# 906014

# %%
nonfoodviolations = len(df[(df["violation_code"] == "F033")]) # worth 4 points which could bring down a restaurant's rating down fast
tempviolations = len(df[(df["violation_code"] == "F007")])
equipmentviolations = len(df[(df["violation_code"] == "F044")])
lightingviolations = len(df[(df["violation_code"] == "F037")])
utensilapprovalviolation = len(df[(df["violation_code"] == "F035")])

print(nonfoodviolations)
print(tempviolations)
print(equipmentviolations)
print(lightingviolations)
print(utensilapprovalviolation)
# Out:
# 100083
# 41110
# 102012
# 48046
# 80020

# %%
## Removing outliers through Standard Deviation Method

import pandas as pd
Location = "inspections.csv"
df = pd.read_csv(Location)

meanscore = df['score'].mean()
stdscore = df['score'].std()
toprange = meanscore + stdscore * 1.96
botrange = meanscore - stdscore * 1.96

copydf = df
copydf = copydf.drop(copydf[copydf['score'] > toprange].index)
copydf = copydf.drop(copydf[copydf['score'] < botrange].index)
copydf
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#        activity_date employee_id                    facility_address  \
# 0         2017-05-09   EE0000593                 17660 CHATSWORTH ST
# 1         2017-04-10   EE0000126              3615 PACIFIC COAST HWY
# 2         2017-04-04   EE0000593                 17515 CHATSWORTH ST
# 3         2017-08-15   EE0000971            44455 VALLEY CENTRAL WAY
# 4         2016-09-26   EE0000145                      11700 SOUTH ST
# 5         2016-05-11   EE0000720                    1309 S HOOVER ST
# 6         2017-02-28   EE0000741                      4959 PATATA ST
# ...

# %%
import pandas as pd

Location = "inspections.csv"
df = pd.read_csv(Location)

df.head()

bins = [0, 60, 70, 80, 90, 100]

# Create names for the four groups
group_names = ['F', 'D', 'C', 'B', 'A']

df['grade'] = pd.cut(df['score'], bins, labels=group_names)
df.head(5)
# Out:
#   activity_date employee_id          facility_address  facility_city  \
# 0    2017-05-09   EE0000593       17660 CHATSWORTH ST  GRANADA HILLS
# 1    2017-04-10   EE0000126    3615 PACIFIC COAST HWY       TORRANCE
# 2    2017-04-04   EE0000593       17515 CHATSWORTH ST  GRANADA HILLS
# 3    2017-08-15   EE0000971  44455 VALLEY CENTRAL WAY      LANCASTER
# 4    2016-09-26   EE0000145            11700 SOUTH ST        ARTESIA
#
#   facility_id               facility_name facility_state facility_zip grade  \
# 0   FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344     A
# 1   FA0242138              SHAKEY'S PIZZA             CA        90505     A
# 2   FA0007801              BAITH AL HALAL             CA        91344     A
# 3   FA0013858            FOOD 4 LESS #306             CA        93536     A
# 4   FA0179671           PHO LITTLE SAIGON             CA        90701     A
#
#     owner_id                      owner_name  \
# ...

# %%
pd.value_counts(df['grade']) # creating bins
# Out:
# A    156715
# B     32593
# C      1970
# D        86
# F         7
# Name: grade, dtype: int64

# %%
df.describe()
# Out:
#        program_element_pe          score   service_code
# count       191371.000000  191371.000000  191371.000000
# mean          1629.888980      93.753306       7.078246
# std              9.391426       3.845518      48.932257
# min           1610.000000      54.000000       1.000000
# 25%           1631.000000      91.000000       1.000000
# 50%           1632.000000      94.000000       1.000000
# 75%           1635.000000      97.000000       1.000000
# max           1641.000000     100.000000     401.000000

# %%
df['activity_date'].value_counts()
# Out:
# 2016-08-09    562
# 2016-12-13    542
# 2016-12-06    539
# 2016-08-10    531
# 2016-04-20    508
# 2016-12-07    508
# 2017-07-26    507
# 2017-01-24    506
# 2016-12-14    505
# 2016-08-03    504
# 2017-02-07    500
# 2016-08-24    488
# 2017-02-15    485
# 2016-09-28    483
# 2016-02-24    483
# 2017-12-13    481
# 2017-05-10    478
# 2016-01-13    475
# 2016-10-25    474
# 2016-02-17    474
# 2016-07-26    474
# 2016-09-07    473
# 2016-06-21    473
# 2016-09-20    473
# 2016-06-22    468
# 2016-10-19    468
# 2017-05-09    465
# 2016-02-09    464
# 2017-03-22    464
# 2017-03-21    464
#              ...
# 2017-03-11      2
# 2017-12-17      2
# 2017-12-03      2
# 2016-04-02      1
# 2016-12-10      1
# 2016-08-27      1
# 2016-09-11      1
# 2015-08-01      1
# 2017-04-15      1
# 2016-11-19      1
# 2017-05-21      1
# 2017-04-01      1
# 2017-05-06      1
# 2016-11-12      1
# 2017-02-12      1
# 2016-10-16      1
# 2017-11-19      1
# 2017-10-14      1
# 2016-09-24      1
# ...

# %%
# Most inspections happened between June-August of 2016
